# %% [markdown]
# You need at least two methods, i.e. rows, in the .csv file.

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# setwd('/Users/alitinet/Desktop/thesis/multigrate/')

# %%
# %%R
# source('code/PlotSingleAtlas.R')
# plotSingleAtlas('data/10xpbmc10k-2020/metrics.csv')
# Out:
# R[write to console]: Lade nötiges Paket: lattice
#
# R[write to console]: Lade nötiges Paket: survival
#
# R[write to console]: Lade nötiges Paket: Formula
#
# R[write to console]: Lade nötiges Paket: ggplot2
#
# R[write to console]:
# Attache Paket: ‘Hmisc’
#
#
# R[write to console]: Следующие объекты скрыты от ‘package:base’:
#
#     format.pval, units
#
#
# R[write to console]:
# Attache Paket: ‘plyr’
#
#
# R[write to console]: Следующие объекты скрыты от ‘package:Hmisc’:
#
#     is.discrete, summarize
#
#
# R[write to console]:
# Attache Paket: ‘dplyr’
#
#
# R[write to console]: Следующие объекты скрыты от ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# R[write to console]: Следующие объекты скрыты от ‘package:Hmisc’:
#
#     src, summarize
#
#
# R[write to console]: Следующие объекты скрыты от ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: Следующие объекты скрыты от ‘package:base’:
#
# ...
